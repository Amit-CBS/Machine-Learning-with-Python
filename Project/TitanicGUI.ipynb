# %%
# titanic_proj6.py

from tkinter import *
from tkinter import messagebox as msg
from tkintertable import TableCanvas,TableModel
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#ignore warnings
import warnings
warnings.filterwarnings('ignore')
titan_df = pd.read_excel(r'/media/amit/Work/GitHub/Machine Learning with Python/Project/Final/titanic.xls')
  
class TestApp1():
    def __init__(self,root):
        self.f=Frame(root,height=200,width=100)
        self.f.pack(fill=BOTH,expand=1)
        self.table=TableCanvas(self.f,read_only=True)
        titan_df = pd.read_excel(r'/media/amit/Work/GitHub/Machine Learning with Python/Project/Final/titanic.xls')
        titan_df.to_csv(r'/media/amit/Work/GitHub/Machine Learning with Python/Project/Final//titanic.csv',index=None,header=True)
        self.table.importCSV(r'/media/amit/Work/GitHub/Machine Learning with Python/Project/Final/titanic.csv')
        
        print(self.table.model.columnNames)
        self.table.show()

def Convert():
    root = Tk()
    root.title("Titanic.csv")
    root.geometry('800x400')
    obj=ConvertClass(root)
    
def Wrangle():
#     titan_df = pd.read_excel(r'/media/amit/Work/GitHub/Machine Learning with Python/Project/Final/titanic.xls')
    print(1)
    
#     master = Tk()
#     w = Label(master, textvariable=s).pack()
#     w.pack()

def Survived():
    s= titan_df['survived'].value_counts()
    msg.showinfo("Survived",s[1])
    msg.showinfo("Not Survived",s[0])
    
def MSurvived():
    s = titan_df['survived'][titan_df['sex'] == 'male'].value_counts()
    msg.showinfo("Males Survived",s[1])
    msg.showinfo("Males Not Survived",s[0])
    
def FSurvived():
#     s = titan_df['survived'][titan_df['sex'] == 'female'].value_counts()
    msg.showinfo("Females Survived",s[1])
    msg.showinfo("Females Not Survived",s[0])
def Normalize():
    print(1)
    
class ConvertClass():
    def __init__(self,root):
        self.f=Frame(root,height=200,width=100)
        self.f.pack(fill=BOTH,expand=1)
        self.table=TableCanvas(self.f,read_only=True)
        titan_df = pd.read_excel(r'/media/amit/Work/GitHub/Machine Learning with Python/Project/Final/titanic.xls')
        titan_df.to_csv(r'/media/amit/Work/GitHub/Machine Learning with Python/Project/Final/titanic.csv',index=None,header=True)
        self.table.importCSV(r'/media/amit/Work/GitHub/Machine Learning with Python/Project/Final/titanic.csv')
        titan_df = titan_df.dropna(axis = 0, how ='any')
        self.table.titan_df
        msg.showinfo("Wrangle","Data Wrangling has been done to eleminate missing data")    
#----------------------------------------     
root = Tk()
root.title('MainFrame')
root.geometry('600x400')

# Creating widgets
convert = Button(root,text='Convert XLS to CSV', font=('Arial', 14), bg='Orange', fg='Black',command=Convert)
wrangle = Button(root,text='Wrangle', font=('Arial', 14), bg='Khaki', fg='Black', command=Wrangle)
survived = Button(root,text='Survived or not', font=('Arial', 14), bg='Yellow', fg='Black', command=Survived)
mSurvived = Button(root,text='Male Survived or not', font=('Arial', 14), bg='Yellow', fg='Black', command=MSurvived)
fSurvived = Button(root,text='Female Survived or not', font=('Arial', 14), bg='Yellow', fg='Black', command=FSurvived)
normalize = Button(root,text='Normalize survival rate', font=('Arial', 14), bg='Yellow', fg='Black', command=Normalize)

# Placing widgets using grid manager

convert.place(x=100,y=100)
wrangle.place(x=100,y=150)
survived.place(x=100,y=200)
mSurvived.place(x=100,y=250)
fSurvived.place(x=100,y=300)
normalize.place(x=100,y=350)
# exit_button.place(x=330,y=100)

# mainloop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/amit/anaconda3/lib/python3.7/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-35-fba80abaf0d8>", line 30, in Convert
#     obj=ConvertClass(root)
#   File "<ipython-input-35-fba80abaf0d8>", line 66, in __init__
#     self.table.titan_df
# AttributeError: 'TableCanvas' object has no attribute 'titan_df'
