# %%
import pandas as pd

# %%
#dataset
data1={'Name':['Amar','Anupam','Anshuman'],
      'Roll':[104,94,95],
      'qualification':['B.Tech','B.Tech','B.Tech'],
      }

data2={'Name':['Anvesh','Krishna','ABhishek'],
      'Roll':[92,66,100],
      'qualification':['B.Tech','B.Tech','B.Tech'],
      }

# %%
#Creating dataframe 1
df1=pd.DataFrame(data1,index=[0,1,2])
df1
# Out:
#        Name  Roll qualification
# 0      Amar   104        B.Tech
# 1    Anupam    94        B.Tech
# 2  Anshuman    95        B.Tech

# %%
#creating Dataframe 2
df2=pd.DataFrame(data2,index=[3,4,5])
df2
# Out:
#        Name  Roll qualification
# 3    Anvesh    92        B.Tech
# 4   Krishna    66        B.Tech
# 5  ABhishek   100        B.Tech

# %%
#concatenation
pd.concat([df1,df2])
# Out:
#        Name  Roll qualification
# 0      Amar   104        B.Tech
# 1    Anupam    94        B.Tech
# 2  Anshuman    95        B.Tech
# 3    Anvesh    92        B.Tech
# 4   Krishna    66        B.Tech
# 5  ABhishek   100        B.Tech

# %%
#dataset
data3={'Name':['Amar','Anupam','Anshuman'],
      'Roll':[104,94,95],
      'qualification':['B.Tech','B.Tech','B.Tech'],
      }


data4={'Adress':['jharkhand','Bihar','Kolkata'],
      'Roll':[104,94,95],
      'Age':[100,101,102],
      }

# %%
#creating Dataframe 3
df3=pd.DataFrame(data3)
df3
# Out:
#        Name  Roll qualification
# 0      Amar   104        B.Tech
# 1    Anupam    94        B.Tech
# 2  Anshuman    95        B.Tech

# %%
#creating Dataframe 4
df4=pd.DataFrame(data4)
df4
# Out:
#       Adress  Roll  Age
# 0  jharkhand   104  100
# 1      Bihar    94  101
# 2    Kolkata    95  102

# %%
#merge function()
res=pd.merge(df3,df4,on="Roll")
res
# Out:
#        Name  Roll qualification     Adress  Age
# 0      Amar   104        B.Tech  jharkhand  100
# 1    Anupam    94        B.Tech      Bihar  101
# 2  Anshuman    95        B.Tech    Kolkata  102

# %%
res=df1.append(df2)
res
# Out:
#        Name  Roll qualification
# 0      Amar   104        B.Tech
# 1    Anupam    94        B.Tech
# 2  Anshuman    95        B.Tech
# 3    Anvesh    92        B.Tech
# 4   Krishna    66        B.Tech
# 5  ABhishek   100        B.Tech

# %%
#reading csv file and converting into dataframe
weather=pd.read_csv(r"C:\Users\amark\Downloads\weather.csv")
weather
# Out:
#            date  maximum temperature  minimum temperature  \
# 0    01-01-2016                 42.0                 34.0
# 1    02-01-2016                 40.0                 32.0
# 2    03-01-2016                 45.0                 35.0
# 3    04-01-2016                 36.0                 14.0
# 4    05-01-2016                 29.0                 11.0
# ..          ...                  ...                  ...
# 361  27-12-2016                 60.0                 40.0
# 362  28-12-2016                 40.0                 34.0
# 363  29-12-2016                 46.0                 33.0
# 364  30-12-2016                 40.0                 33.0
# 365  31-12-2016                 44.0                 31.0
#
#      average temperature precipitation snow fall snow depth        Summary
# 0                   38.0             0         0          0  Partly Cloudy
# 1                   36.0             0         0          0  Partly Cloudy
# 2                   40.0             0         0          0  Mostly Cloudy
# 3                   25.0             0         0          0  Partly Cloudy
# 4                   20.0             0         0          0  Mostly Cloudy
# ..                   ...           ...       ...        ...            ...
# 361                 50.0             0         0          0          Clear
# 362                 37.0             0         0          0  Partly Cloudy
# 363                 39.5          0.39         0          0          Clear
# 364                 36.5          0.01         T          0          Foggy
# 365                 37.5             0         0          0          Foggy
#
# [366 rows x 8 columns]

# %%
weather.shape
# Out:
# (366, 8)

# %%
weather.head()
# Out:
#          date  maximum temperature  minimum temperature  average temperature  \
# 0  01-01-2016                 42.0                 34.0                 38.0
# 1  02-01-2016                 40.0                 32.0                 36.0
# 2  03-01-2016                 45.0                 35.0                 40.0
# 3  04-01-2016                 36.0                 14.0                 25.0
# 4  05-01-2016                 29.0                 11.0                 20.0
#
#   precipitation snow fall snow depth        Summary
# 0             0         0          0  Partly Cloudy
# 1             0         0          0  Partly Cloudy
# 2             0         0          0  Mostly Cloudy
# 3             0         0          0  Partly Cloudy
# 4             0         0          0  Mostly Cloudy

# %%
weather.tail()
# Out:
#            date  maximum temperature  minimum temperature  \
# 361  27-12-2016                 60.0                 40.0
# 362  28-12-2016                 40.0                 34.0
# 363  29-12-2016                 46.0                 33.0
# 364  30-12-2016                 40.0                 33.0
# 365  31-12-2016                 44.0                 31.0
#
#      average temperature precipitation snow fall snow depth        Summary
# 361                 50.0             0         0          0          Clear
# 362                 37.0             0         0          0  Partly Cloudy
# 363                 39.5          0.39         0          0          Clear
# 364                 36.5          0.01         T          0          Foggy
# 365                 37.5             0         0          0          Foggy

# %%
w=weather.iloc[10:21,0:3]
w
# Out:
#           date  maximum temperature  minimum temperature
# 10  11-01-2016                 40.0                 26.0
# 11  12-01-2016                 44.0                 25.0
# 12  13-01-2016                 30.0                 22.0
# 13  14-01-2016                 38.0                 22.0
# 14  15-01-2016                 51.0                 34.0
# 15  16-01-2016                 52.0                 42.0
# 16  17-01-2016                 42.0                 30.0
# 17  18-01-2016                 31.0                 18.0
# 18  19-01-2016                  NaN                 16.0
# 19  20-01-2016                 37.0                 27.0
# 20  21-01-2016                 36.0                 26.0

# %%
x=weather.iloc[:5,0]
y=weather.iloc[:5,1]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.hist(y)
# Out:
# (array([1., 0., 0., 0., 1., 0., 1., 0., 1., 1.]),
#  array([29. , 30.6, 32.2, 33.8, 35.4, 37. , 38.6, 40.2, 41.8, 43.4, 45. ]),
#  <a list of 10 Patch objects>)

# %%
#feature engineering




#checking missing values
weather.isnull().sum()
# Out:
# date                   0
# maximum temperature    2
# minimum temperature    0
# average temperature    0
# precipitation          0
# snow fall              1
# snow depth             2
# Summary                0
# dtype: int64

# %%
#printing maximum temperature column
weather['maximum temperature']
# Out:
# 0      42.0
# 1      40.0
# 2      45.0
# 3      36.0
# 4      29.0
#        ...
# 361    60.0
# 362    40.0
# 363    46.0
# 364    40.0
# 365    44.0
# Name: maximum temperature, Length: 366, dtype: float64

# %%
#filling missing values with mean median mode function
weather['maximum temperature'].fillna(weather['maximum temperature'].mean(),inplace=True)
weather
# Out:
#            date  maximum temperature  minimum temperature  \
# 0    01-01-2016                 42.0                 34.0
# 1    02-01-2016                 40.0                 32.0
# 2    03-01-2016                 45.0                 35.0
# 3    04-01-2016                 36.0                 14.0
# 4    05-01-2016                 29.0                 11.0
# ..          ...                  ...                  ...
# 361  27-12-2016                 60.0                 40.0
# 362  28-12-2016                 40.0                 34.0
# 363  29-12-2016                 46.0                 33.0
# 364  30-12-2016                 40.0                 33.0
# 365  31-12-2016                 44.0                 31.0
#
#      average temperature precipitation snow fall snow depth        Summary
# 0                   38.0             0         0          0  Partly Cloudy
# 1                   36.0             0         0          0  Partly Cloudy
# 2                   40.0             0         0          0  Mostly Cloudy
# 3                   25.0             0         0          0  Partly Cloudy
# 4                   20.0             0         0          0  Mostly Cloudy
# ..                   ...           ...       ...        ...            ...
# 361                 50.0             0         0          0          Clear
# 362                 37.0             0         0          0  Partly Cloudy
# 363                 39.5          0.39         0          0          Clear
# 364                 36.5          0.01         T          0          Foggy
# 365                 37.5             0         0          0          Foggy
#
# [366 rows x 8 columns]

# %%
weather.isnull().sum()
# Out:
# date                   0
# maximum temperature    0
# minimum temperature    0
# average temperature    0
# precipitation          0
# snow fall              1
# snow depth             2
# Summary                0
# dtype: int64

# %%
#mode return list nd 0 index return most frequent one
weather['snow fall'].fillna(weather['snow fall'].mode()[0],inplace=True)
weather
# Out:
#            date  maximum temperature  minimum temperature  \
# 0    01-01-2016                 42.0                 34.0
# 1    02-01-2016                 40.0                 32.0
# 2    03-01-2016                 45.0                 35.0
# 3    04-01-2016                 36.0                 14.0
# 4    05-01-2016                 29.0                 11.0
# ..          ...                  ...                  ...
# 361  27-12-2016                 60.0                 40.0
# 362  28-12-2016                 40.0                 34.0
# 363  29-12-2016                 46.0                 33.0
# 364  30-12-2016                 40.0                 33.0
# 365  31-12-2016                 44.0                 31.0
#
#      average temperature precipitation snow fall snow depth        Summary
# 0                   38.0             0         0          0  Partly Cloudy
# 1                   36.0             0         0          0  Partly Cloudy
# 2                   40.0             0         0          0  Mostly Cloudy
# 3                   25.0             0         0          0  Partly Cloudy
# 4                   20.0             0         0          0  Mostly Cloudy
# ..                   ...           ...       ...        ...            ...
# 361                 50.0             0         0          0          Clear
# 362                 37.0             0         0          0  Partly Cloudy
# 363                 39.5          0.39         0          0          Clear
# 364                 36.5          0.01         T          0          Foggy
# 365                 37.5             0         0          0          Foggy
#
# [366 rows x 8 columns]

# %%
weather.isnull().sum()
# Out:
# date                   0
# maximum temperature    0
# minimum temperature    0
# average temperature    0
# precipitation          0
# snow fall              0
# snow depth             2
# Summary                0
# dtype: int64

# %%
#method inside fillna() fill the missing place with forward or backward value usin ffill or bfill
weather['snow depth'].fillna(method="ffill",inplace=True)
weather
# Out:
#            date  maximum temperature  minimum temperature  \
# 0    01-01-2016                 42.0                 34.0
# 1    02-01-2016                 40.0                 32.0
# 2    03-01-2016                 45.0                 35.0
# 3    04-01-2016                 36.0                 14.0
# 4    05-01-2016                 29.0                 11.0
# ..          ...                  ...                  ...
# 361  27-12-2016                 60.0                 40.0
# 362  28-12-2016                 40.0                 34.0
# 363  29-12-2016                 46.0                 33.0
# 364  30-12-2016                 40.0                 33.0
# 365  31-12-2016                 44.0                 31.0
#
#      average temperature precipitation snow fall snow depth        Summary
# 0                   38.0             0         0          0  Partly Cloudy
# 1                   36.0             0         0          0  Partly Cloudy
# 2                   40.0             0         0          0  Mostly Cloudy
# 3                   25.0             0         0          0  Partly Cloudy
# 4                   20.0             0         0          0  Mostly Cloudy
# ..                   ...           ...       ...        ...            ...
# 361                 50.0             0         0          0          Clear
# 362                 37.0             0         0          0  Partly Cloudy
# 363                 39.5          0.39         0          0          Clear
# 364                 36.5          0.01         T          0          Foggy
# 365                 37.5             0         0          0          Foggy
#
# [366 rows x 8 columns]

# %%
weather.isnull().sum()
# Out:
# date                   0
# maximum temperature    0
# minimum temperature    0
# average temperature    0
# precipitation          0
# snow fall              0
# snow depth             0
# Summary                0
# dtype: int64
